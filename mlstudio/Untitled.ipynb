# %%
import mltable
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

ml_client = MLClient.from_config(credential=DefaultAzureCredential())
data_asset = ml_client.data.get("automobile_prices", version="1")

tbl = mltable.load(f'azureml:/{data_asset.id}')

df = tbl.to_pandas_dataframe()
df
# Out:
# Found the config file in: /config.json
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Overriding of current MeterProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                NA      ferrari       gas        std
# 1            3                NA  alfa-romero       gas        std
# 2            3                NA  alfa-romero       gas        std
# 3            1                NA  alfa-romero       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 201         -1                95        volvo       gas        std
# 202         -1                95        volvo       gas      turbo
# 203         -1                95        volvo       gas        std
# 204         -1                95        volvo    diesel      turbo
# 205         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# 1            two  convertible          rwd           front        88.6  ...
# 2            two  convertible          rwd           front        88.6  ...
# 3            two    hatchback          rwd           front        94.5  ...
# 4           four        sedan          fwd           front        99.8  ...
# ..           ...          ...          ...             ...         ...  ...
# 201         four        sedan          rwd           front       109.1  ...
# 202         four        sedan          rwd           front       109.1  ...
# 203         four        sedan          rwd           front       109.1  ...
# 204         four        sedan          rwd           front       109.1  ...
# 205         four        sedan          rwd           front       109.1  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0            130         mpfi  3.47    2.68               9.0        111
# 1            130         mpfi  3.47    2.68               9.0        111
# 2            130         mpfi  3.47    2.68               9.0        111
# 3            152         mpfi  2.68    3.47               9.0        154
# 4            109         mpfi  3.19     3.4              10.0        102
# ..           ...          ...   ...     ...               ...        ...
# 201          141         mpfi  3.78    3.15               9.5        114
# 202          141         mpfi  3.78    3.15               8.7        160
# 203          173         mpfi  3.58    2.87               8.8        134
# 204          145          idi  3.01     3.4              23.0        106
# 205          141         mpfi  3.78    3.15               9.5        114
#
#      peak-rpm city-mpg highway-mpg   price
# 0        5000       21          27  113495
# 1        5000       21          27   13495
# 2        5000       21          27   16500
# 3        5000       19          26   16500
# 4        5500       24          30   13950
# ..        ...      ...         ...     ...
# 201      5400       23          28   16845
# 202      5300       19          25   19045
# 203      5500       18          23   21485
# 204      4800       26          27   22470
# 205      5400       19          25   22625
#
# [206 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          206 non-null    int64
#  1   normalized-losses  206 non-null    object
#  2   make               206 non-null    object
#  3   fuel-type          206 non-null    object
#  4   aspiration         206 non-null    object
#  5   num-of-doors       206 non-null    object
#  6   body-style         206 non-null    object
#  7   drive-wheels       206 non-null    object
#  8   engine-location    206 non-null    object
#  9   wheel-base         206 non-null    float64
#  10  length             206 non-null    float64
#  11  width              206 non-null    float64
#  12  height             206 non-null    float64
#  13  curb-weight        206 non-null    int64
#  14  engine-type        206 non-null    object
#  15  num-of-cylinders   206 non-null    object
#  16  engine-size        206 non-null    int64
#  17  fuel-system        206 non-null    object
#  18  bore               206 non-null    object
#  19  stroke             206 non-null    object
#  20  compression-ratio  206 non-null    float64
#  21  horsepower         206 non-null    object
#  22  peak-rpm           206 non-null    object
#  23  city-mpg           206 non-null    int64
#  24  highway-mpg        206 non-null    int64
#  25  price              206 non-null    int64
# dtypes: float64(5), int64(6), object(15)
# memory usage: 42.0+ KB

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  206.000000  206.000000  206.000000  206.000000  206.000000
# mean     0.844660   98.707282  174.023786   65.899029   53.700971
# std      1.251398    6.048608   12.312594    2.143669    2.461588
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.425000   64.100000   52.000000
# 50%      1.000000   96.950000  173.200000   65.500000   54.100000
# 75%      2.000000  102.300000  182.750000   66.825000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg  \
# count   206.000000   206.000000          206.00000  206.000000   206.000000
# mean   2555.529126   126.922330           10.13699   25.199029    30.733010
# std     519.408967    41.541561            3.96314    6.532784     6.874596
# min    1488.000000    61.000000            7.00000   13.000000    16.000000
# 25%    2151.000000    97.250000            8.60000   19.000000    25.000000
# 50%    2417.000000   120.000000            9.00000   24.000000    30.000000
# 75%    2932.750000   141.000000            9.40000   30.000000    34.000000
# max    4066.000000   326.000000           23.00000   49.000000    54.000000
#
#                price
# count     206.000000
# mean    13898.844660
# std     10801.559552
# min      5118.000000
# 25%      7790.750000
# 50%     10320.000000
# 75%     16512.000000
# max    113495.000000

# %%
df.groupby("make")["price"].mean().sort_values(ascending= False).plot(kind="bar")
# Out:
# <Axes: xlabel='make'>
